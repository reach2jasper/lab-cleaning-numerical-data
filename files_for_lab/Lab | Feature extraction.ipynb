# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %% [markdown]
# ## 1.- Open the categorical dataframe we created before.

# %%
categorical = pd.read_csv('categorical.csv')
categorical.head()
# Out:
#   customer       state response  coverage education employmentstatus gender  \
# 0  BU79786  Washington       No     Basic  Bachelor         Employed      F
# 1  QZ44356     Arizona       No  Extended  Bachelor       Unemployed      F
# 2  AI49188      Nevada       No   Premium  Bachelor         Employed      F
# 3  WW63253  California       No     Basic  Bachelor       Unemployed      M
# 4  HB64268  Washington       No     Basic  Bachelor         Employed      M
#
#   location_code marital_status     policy_type            policy  \
# 0      Suburban        Married  Corporate Auto    Corporate High
# 1      Suburban         Single   Personal Auto     Personal High
# 2      Suburban        Married   Personal Auto     Personal High
# 3      Suburban        Married  Corporate Auto  Corporate Medium
# 4         Rural         Single   Personal Auto      Personal Low
#
#    renew_offer_type sales_channel  vehicle_class vehicle_size
# 0                 1         Agent   Two-Door Car      Medsize
# 1                 3         Agent  Four-Door Car      Medsize
# 2                 1         Agent   Two-Door Car      Medsize
# 3                 1   Call Center            SUV      Medsize
# 4                 1         Agent  Four-Door Car      Medsize

# %% [markdown]
# ## 2.- Plot all the categorical variables with the proper plot. What can you see?

# %%
for col in categorical.columns:
    sns.countplot(x=col, data=categorical)
    plt.show()

# %% [markdown]
# ## 3.- There might be some columns that seem to be redundant, check their values to be sure. What should we do with them?
# Make any changes you feel are necessary.

# %%
#I am not making any changes

# %% [markdown]
# ## 4.- Plot time variable. Can you extract something from it?

# %%
categorical['effective_to_date'] = pd.to_datetime(categorical['effective_to_date'], errors='coerce')
categorical['effective_to_date']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'effective_to_date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-105eb2fb3d53> in <module>
# ----> 1 categorical['effective_to_date'] = pd.to_datetime(categorical['effective_to_date'], errors='coerce')
#       2 categorical['effective_to_date']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'effective_to_date'
