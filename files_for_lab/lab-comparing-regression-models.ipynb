# %%
import scipy.stats as st
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cat = pd.read_csv('cat.csv')
cat
# Out:
#            state response  coverage education effective_to_date  \
# 0     Washington       No     Basic  Bachelor           2/24/11
# 1        Arizona       No  Extended  Bachelor           1/31/11
# 2         Nevada       No   Premium  Bachelor           2/19/11
# 3     California       No     Basic  Bachelor           1/20/11
# 4     Washington       No     Basic  Bachelor            2/3/11
# ...          ...      ...       ...       ...               ...
# 9129  California       No     Basic  Bachelor           2/10/11
# 9130  California      Yes  Extended   College           2/12/11
# 9131  California       No  Extended  Bachelor            2/6/11
# 9132  California       No  Extended   College            2/3/11
# 9133  California       No  Extended   College           2/14/11
#
#      employmentstatus gender location_code marital_status        policy  \
# 0            Employed      F      Suburban        Married  Corporate L3
# 1          Unemployed      F      Suburban         Single   Personal L3
# 2            Employed      F      Suburban        Married   Personal L3
# 3          Unemployed      M      Suburban        Married  Corporate L2
# 4            Employed      M         Rural         Single   Personal L1
# ...               ...    ...           ...            ...           ...
# 9129         Employed      M         Urban        Married   Personal L1
# 9130         Employed      F      Suburban       Divorced  Corporate L3
# 9131       Unemployed      M      Suburban         Single  Corporate L2
# 9132         Employed      M      Suburban        Married   Personal L2
# 9133       Unemployed      M      Suburban         Single  Corporate L3
#
#      renew_offer_type sales_channel  vehicle_class vehicle_size
# 0              Offer1         Agent   Two-Door Car      Medsize
# 1              Offer3         Agent  Four-Door Car      Medsize
# 2              Offer1         Agent   Two-Door Car      Medsize
# 3              Offer1   Call Center            SUV      Medsize
# 4              Offer1         Agent  Four-Door Car      Medsize
# ...               ...           ...            ...          ...
# 9129           Offer2           Web  Four-Door Car      Medsize
# 9130           Offer1        Branch  Four-Door Car      Medsize
# 9131           Offer1        Branch  Four-Door Car      Medsize
# 9132           Offer3        Branch  Four-Door Car        Large
# 9133           Offer4   Call Center   Two-Door Car      Medsize
#
# [9134 rows x 14 columns]

# %%
num = pd.read_csv('num.csv')
num
#num.isna().sum()
data = pd.concat([cat,num], axis=1)
data
#data=data.dropna(axis=0)
#data.isna().sum()
# Out:
#            state response  coverage education effective_to_date  \
# 0     Washington       No     Basic  Bachelor           2/24/11
# 1        Arizona       No  Extended  Bachelor           1/31/11
# 2         Nevada       No   Premium  Bachelor           2/19/11
# 3     California       No     Basic  Bachelor           1/20/11
# 4     Washington       No     Basic  Bachelor            2/3/11
# ...          ...      ...       ...       ...               ...
# 9129  California       No     Basic  Bachelor           2/10/11
# 9130  California      Yes  Extended   College           2/12/11
# 9131  California       No  Extended  Bachelor            2/6/11
# 9132  California       No  Extended   College            2/3/11
# 9133  California       No  Extended   College           2/14/11
#
#      employmentstatus gender location_code marital_status        policy  ...  \
# 0            Employed      F      Suburban        Married  Corporate L3  ...
# 1          Unemployed      F      Suburban         Single   Personal L3  ...
# 2            Employed      F      Suburban        Married   Personal L3  ...
# 3          Unemployed      M      Suburban        Married  Corporate L2  ...
# 4            Employed      M         Rural         Single   Personal L1  ...
# ...               ...    ...           ...            ...           ...  ...
# 9129         Employed      M         Urban        Married   Personal L1  ...
# 9130         Employed      F      Suburban       Divorced  Corporate L3  ...
# 9131       Unemployed      M      Suburban         Single  Corporate L2  ...
# 9132         Employed      M      Suburban        Married   Personal L2  ...
# 9133       Unemployed      M      Suburban         Single  Corporate L3  ...
#
#       vehicle_class vehicle_size customer_lifetime_value income  \
# 0      Two-Door Car      Medsize             2763.519279  56274
# 1     Four-Door Car      Medsize             6979.535903      0
# 2      Two-Door Car      Medsize            12887.431650  48767
# 3               SUV      Medsize             7645.861827      0
# 4     Four-Door Car      Medsize             2813.692575  43836
# ...             ...          ...                     ...    ...
# 9129  Four-Door Car      Medsize            23405.987980  71941
# 9130  Four-Door Car      Medsize             3096.511217  21604
# 9131  Four-Door Car      Medsize             8163.890428      0
# 9132  Four-Door Car        Large             7524.442436  21941
# 9133   Two-Door Car      Medsize             2611.836866      0
#
#       monthly_premium_auto  months_since_last_claim  \
# 0                       69                       32
# 1                       94                       13
# 2                      108                       18
# 3                      106                       18
# 4                       73                       12
# ...                    ...                      ...
# 9129                    73                       18
# 9130                    79                       14
# 9131                    85                        9
# 9132                    96                       34
# 9133                    77                        3
#
#       months_since_policy_inception  number_of_open_complaints  \
# 0                                 5                          0
# 1                                42                          0
# 2                                38                          0
# 3                                65                          0
# 4                                44                          0
# ...                             ...                        ...
# 9129                             89                          0
# 9130                             28                          0
# 9131                             37                          3
# 9132                              3                          0
# 9133                             90                          0
#
#       number_of_policies  total_claim_amount
# 0                      1          384.811147
# 1                      8         1131.464935
# 2                      2          566.472247
# 3                      7          529.881344
# 4                      1          138.130879
# ...                  ...                 ...
# 9129                   2          198.234764
# 9130                   1          379.200000
# 9131                   2          790.784983
# 9132                   3          691.200000
# 9133                   1          369.600000
#
# [9134 rows x 22 columns]

# %%
#Separating Target and features
y = data['income']
X = data.drop(['income'], axis=1)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1337)
# Separate X_train and X_test into numerical and categorical (X_train_cat , X_train_num , X_test_cat , X_test_num)
#TRAIN
X_train_num = X_train.select_dtypes(include=[np.number])
X_train_cat = X_train.select_dtypes(include=['object'])
#TEST
X_test_num = X_test.select_dtypes(include=[np.number])
X_test_cat = X_test.select_dtypes(include=['object'])

# %%
#Scaling usung standard scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_num_scaled = scaler.fit_transform(X_train_num)
X_test_num_scaled = scaler.transform(X_test_num)

# %%
#Converting the string to Numerical using OneHot Encoder
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(handle_unknown='ignore')
X_train_cat_encoded = encoder.fit_transform(X_train_cat)
X_test_cat_encoded = encoder.transform(X_test_cat)

#Concatenating the numerical and encoded values
X_train_encoded = pd.concat([pd.DataFrame(X_train_num_scaled), pd.DataFrame(X_train_cat_encoded.toarray())], axis=1)
X_test_encoded = pd.concat([pd.DataFrame(X_test_num_scaled), pd.DataFrame(X_test_cat_encoded.toarray())], axis=1)

# %%
#Function to compare all the models
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error

def train_test_models(models, X_train, y_train, X_test, y_test):
    mse_values = []
    for model in models:
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        mse = mean_squared_error(y_test, y_pred)
        mse_values.append(mse)
    return mse_values
        
models = [LinearRegression(), KNeighborsRegressor(), MLPRegressor()]
mse_values = train_test_models(models, X_train_encoded, y_train, X_test_encoded, y_test)
print(mse_values)
# Out:
# [299189664.0377668, 430093297.0929831, 514717351.66367966]
# /Users/jasper/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
