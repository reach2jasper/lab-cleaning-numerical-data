# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('numerical.csv') 
data.head()
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    number_of_open_complaints  number_of_policies  total_claim_amount
# 0                          0                   1          384.811147
# 1                          0                   8         1131.464935
# ...

# %%
#Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.
data.hist(bins=15, figsize=(15, 6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe302056130>,
# ...
#       dtype=object)

# %%
#Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.
#Creating a function for log transformation
def log_transform_clean_(x):
    if np.isfinite(x) and x!=0: 
        return np.log(x)
    else:
        return np.NAN
    
for i in data.columns:
    data[i]=list(map(log_transform_clean_,data[i]))

# %%
#Plot after log transformation
sns.set(rc={'figure.figsize':(2,1)})
for i in data.columns:
    sns.distplot(data[i])
    plt.show()
# Out:
# <ipython-input-10-6e3196d893db>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[i])
# <ipython-input-10-6e3196d893db>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[i])
# <ipython-input-10-6e3196d893db>:4: UserWarning:
#
# ...
